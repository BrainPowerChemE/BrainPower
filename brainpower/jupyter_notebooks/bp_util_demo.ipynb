# %%
import pandas as pd
import numpy as np
import scipy.stats
import altair as alt

# %%
os.path.relpath('/home/jwerner/BrainPower/brainpower/submodule/')
# Out:
# '../submodule'

# %%
import ../submodule
# Out:
#   Cell In[4], line 1
#     import ../submodule
#            ^
# SyntaxError: invalid syntax

# %%
import sys
sys.path.append('~/BrainPower/brainpower/submodule/')
import bp_util
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 3
#       1 import sys
#       2 sys.path.append('~/BrainPower/brainpower/submodule/')
# ----> 3 import bp_util
#
# ModuleNotFoundError: No module named 'bp_util'

# %%
df_full = pd.read_csv('https://github.com/BrainPowerChemE/brainpowerdata/blob/main/raw_data/full_data.csv?raw=True')

# %%
df_full, dict_proteins = bp_util.clean_raw_bp_data(df_full)

# %%
df_full
# Out:
#             assay_ID       KV37      LV469      LV861      LVX54      LV746  \
# group
# AD_MCI      TPAD0210  28.898373  24.125336  22.676771  20.327832  25.570557
# AD_MCI      TPAD0262  28.915048  22.824361  23.197649  19.990306  25.316286
# AD_MCI      TPAD0266  28.274292  24.358802  24.066243  23.589011  26.241142
# AD_MCI      TPAD0273  29.193195  22.187373  23.550432  20.329372  25.789922
# AD_MCI      TPAD0292  28.212282  22.520379  24.504620  20.681650  26.287648
# ...              ...        ...        ...        ...        ...        ...
# PD_MCI_LBD  TPAD0481  28.131446  22.064598  21.473568  20.811029  24.925192
# PD_MCI_LBD  TPAD0482  28.156999  24.163694  23.342793  15.607011  25.250506
# PD_MCI_LBD  TPAD0483  29.919698  23.727972  24.024882  16.081469  26.457936
# PD_MCI_LBD  TPAD0493  29.254995  22.621331  23.667065  23.309039  26.553185
# PD_MCI_LBD  TPAD0504  28.559131  22.278306  23.775888  21.018388  26.086360
#
# ...

# %%
dict_proteins['ABC']

# %%
import pandas as pd
import numpy as np
import scipy.stats
import altair as alt

# %%
import sys
sys.path.append('/home/jwerner/BrainPower/brainpower/submodule/')
import bp_util

# %%
df_full = pd.read_csv('https://github.com/BrainPowerChemE/brainpowerdata/blob/main/raw_data/full_data.csv?raw=True')

# %%
df_full, dict_proteins = bp_util.clean_raw_bp_data(df_full)

# %%
df_full
# Out:
#           group  assay_ID       KV37      LV469      LV861      LVX54  \
# 0        AD_MCI  TPAD0210  28.898373  24.125336  22.676771  20.327832
# 1        AD_MCI  TPAD0262  28.915048  22.824361  23.197649  19.990306
# 2        AD_MCI  TPAD0266  28.274292  24.358802  24.066243  23.589011
# 3        AD_MCI  TPAD0273  29.193195  22.187373  23.550432  20.329372
# 4        AD_MCI  TPAD0292  28.212282  22.520379  24.504620  20.681650
# ..          ...       ...        ...        ...        ...        ...
# 275  PD_MCI_LBD  TPAD0481  28.131446  22.064598  21.473568  20.811029
# 276  PD_MCI_LBD  TPAD0482  28.156999  24.163694  23.342793  15.607011
# 277  PD_MCI_LBD  TPAD0483  29.919698  23.727972  24.024882  16.081469
# 278  PD_MCI_LBD  TPAD0493  29.254995  22.621331  23.667065  23.309039
# 279  PD_MCI_LBD  TPAD0504  28.559131  22.278306  23.775888  21.018388
#
#          LV746      LV218      LV316      LV312  ...      EMIL3      ABCD2  \
# 0    25.570557  24.797337  23.543465  22.555490  ...  20.373782  19.310236
# 1    25.316286  23.571908  24.051694  22.300534  ...  17.709244        NaN
# 2    26.241142  26.079288  24.586944  24.266694  ...  20.682527        NaN
# 3    25.789922  24.700275  23.881087  22.998723  ...  20.929981  22.488293
# 4    26.287648  25.020801  23.176368  23.293055  ...  21.209263        NaN
# ..         ...        ...        ...        ...  ...        ...        ...
# 275  24.925192  23.815794  22.649795  22.365696  ...  20.486185        NaN
# 276  25.250506  24.746199  24.264510  21.975955  ...        NaN        NaN
# 277  26.457936  25.880806  24.292395  23.740719  ...        NaN        NaN
# 278  26.553185  24.716706  23.063840  22.399448  ...  20.117850        NaN
# 279  26.086360  24.324905  23.584053  23.148672  ...  21.583891  22.375428
#
#           TEN1      PCDAD      ITM2B       ADSV  A0A1W2PRN1       APOF  \
# 0    17.856492  18.453124        NaN  20.879716   24.781034        NaN
# 1    16.816413  17.987179        NaN        NaN         NaN  19.805173
# 2          NaN        NaN        NaN        NaN         NaN        NaN
# 3    17.568634  16.772132  16.934531  18.446332   24.750659        NaN
# 4    18.116146  18.547994  18.692276        NaN         NaN  20.264877
# ..         ...        ...        ...        ...         ...        ...
# 275        NaN  19.603221  17.691827  19.303921         NaN  22.159498
# 276        NaN        NaN        NaN        NaN         NaN        NaN
# 277        NaN        NaN        NaN        NaN         NaN        NaN
# 278        NaN  15.844641  15.265794  20.190391         NaN  20.998117
# 279  18.061359  16.787914  19.279301  20.988465   24.890021        NaN
#
#          DCBD2       LMF2
# 0          NaN        NaN
# 1    21.125776        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4    21.677769  16.254727
# ..         ...        ...
# 275        NaN  13.719437
# 276        NaN        NaN
# 277        NaN        NaN
# 278        NaN  16.722097
# 279        NaN        NaN
#
# [280 rows x 1347 columns]

# %%
dict_proteins['ABCD2']
# Out:
# 'FEQLDTAIRLTLSEEK @ sp|Q9UBJ2|ABCD2'

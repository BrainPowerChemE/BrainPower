# %%
import pandas as pd
import numpy as np
import scipy.stats
import sklearn.linear_model
import sklearn.neighbors

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
sns.set_context('talk')

import warnings
warnings.filterwarnings("ignore")

import mlxtend.feature_selection

# %%
full_data = pd.read_csv('full_data_short.csv')

# %%
train_data = pd.read_csv('train.csv')
val_data = pd.read_csv('val.csv')
test_data = pd.read_csv('test.csv')

# %%
list_full_data_columns = list(full_data.columns)
list_train_data_columns = list(train_data.columns)

# %%
list_dropped_features = list(set(list_full_data_columns).difference(set(list_train_data_columns)))

# %%
print('train_data shape:',np.shape(np.array(train_data)))
print('val_data shape:',np.shape(np.array(val_data)))
print('test_data shape:',np.shape(np.array(test_data)))
print('full_data shape:',np.shape(np.array(full_data)))
# Out:
# train_data shape: (202, 1139)
# val_data shape: (36, 1139)
# test_data shape: (42, 1139)
# full_data shape: (280, 1347)

# %% [markdown]
# Inspecting the data reveals that 200 or so proteins were excluded due to NaN values

# %% [markdown]
# Split the training and validation data into groups

# %%
train_data
# Out:
#           group       KV37      LV469      LV861      LVX54      LV746  \
# 0       Healthy  28.398290  23.968009  24.296234  21.073690  24.306090
# 1       Healthy  28.493880  21.512320  22.687815  22.182946  24.306486
# 2       Healthy  28.860446  22.780248  24.378107  23.365133  25.866827
# 3       Healthy  28.780151  22.422778  22.902736  21.364631  25.018863
# 4       Healthy  28.277717  24.656308  24.440401  22.411287  26.695574
# ..          ...        ...        ...        ...        ...        ...
# 197     Healthy  28.158586  21.952626  23.201193  21.006439  25.086022
# 198          PD  28.185324  22.250517  23.253823  21.194145  25.206602
# 199  PD_MCI_LBD  27.312868  22.469750  21.808856  22.077800  26.440536
# 200     Healthy  27.906681  22.416611  23.390858  18.371032  26.355765
# 201     Healthy  29.755736  23.790572  23.652775  24.220348  27.039265
#
#          LV218      LV316      LV312      LV310  ...      ARMD4      C1QT5  \
# 0    20.834275  22.875021  21.873272  22.012922  ...  18.424523  19.702409
# 1    23.766681  22.963114  22.786492  22.369101  ...  17.826979  19.526250
# 2    22.743360  23.808291  22.685879  22.985000  ...  18.153627  20.114505
# 3    24.221923  23.466170  22.392122  21.878784  ...  14.228847  20.311589
# 4    26.185975  24.878200  23.932789  24.279117  ...  16.580325  19.468810
# ..         ...        ...        ...        ...  ...        ...        ...
# 197  24.276773  23.159882  22.978791  22.439971  ...  17.911971  20.330860
# 198  23.695250  22.543163  21.755287  22.051425  ...  18.185042  19.820794
# 199  24.833839  22.943242  22.217539  22.220150  ...  18.413029  20.109011
# 200  23.609924  22.921723  21.936902  22.170309  ...  18.103972  19.795203
# 201  25.275175  23.885631  23.027617  23.177344  ...  18.222600  19.989506
#
#          B2L12      PLXA4      B3GN2      PCDGL      AGRB1       RECK  \
# 0    28.571054  17.582277  19.833578  17.908683  21.082685  19.540313
# 1    27.953139  18.670746  18.612532  19.756105  21.337060  19.896682
# 2    27.944534  18.229467  19.640964  18.612921  21.079712  19.559118
# 3    28.000618  17.943092  20.497359  19.247203  21.691704  20.267159
# 4    28.342385  17.563858  19.788633  18.069438  21.078241  19.565659
# ..         ...        ...        ...        ...        ...        ...
# 197  28.611495  18.646857  19.733981  17.915158  21.077880  19.101285
# 198  27.770040  18.378343  20.378248  19.015282  21.220598  18.624962
# 199  28.308943  19.640486  20.524291  17.673355  21.588789  20.221517
# 200  28.039519  18.147929  19.988414  18.120577  21.360518  19.704548
# 201  27.500566  17.207086  20.173774  16.832004  21.057444  19.602131
#
#           PSA1      F174A
# 0    20.402270  24.200471
# 1    20.481528  24.270255
# 2    20.400989  24.200733
# 3    20.199615  24.667232
# 4    20.400481  24.200606
# ..         ...        ...
# 197  20.973856  24.481528
# 198  20.498130  24.121522
# 199  21.116644  24.988787
# 200  20.530018  24.254393
# 201  20.395876  24.193588
#
# [202 rows x 1139 columns]

# %%
train_AD_healthy = train_data.loc[(train_data['group'] == 'Healthy') | (train_data['group'] == 'AD_MCI')]
train_PD_healthy = train_data.loc[(train_data['group'] == 'Healthy') | (train_data['group'] == 'PD')]
train_PDMCI_healthy = train_data.loc[(train_data['group'] == 'Healthy') | (train_data['group'] == 'PD_MCI_LBD')]

# %%
val_AD_healthy = val_data.loc[(val_data['group'] == 'Healthy') | (val_data['group'] == 'AD_MCI')]
val_PD_healthy = val_data.loc[(val_data['group'] == 'Healthy') | (val_data['group'] == 'PD')]
val_PDMCI_healthy = train_data.loc[(train_data['group'] == 'Healthy') | (train_data['group'] == 'PD_MCI_LBD')]

# %%
test_AD_healthy = test_data.loc[(test_data['group'] == 'Healthy') | (test_data['group'] == 'AD_MCI')]
test_PD_healthy = test_data.loc[(test_data['group'] == 'Healthy') | (test_data['group'] == 'PD')]
test_PDMCI_healthy = test_data.loc[(test_data['group'] == 'Healthy') | (test_data['group'] == 'PD_MCI_LBD')]

# %%
X_train_AD_healthy = train_AD_healthy.drop(columns='group')
y_train_AD_healthy = train_AD_healthy['group']
X_val_AD_healthy = val_AD_healthy.drop(columns='group')
y_val_AD_healthy = val_AD_healthy['group']
X_test_AD_healthy = test_AD_healthy.drop(columns='group')
y_test_AD_healthy = test_AD_healthy['group']


X_train_PD_healthy = train_PD_healthy.drop(columns='group')
y_train_PD_healthy = train_PD_healthy['group']
X_val_PD_healthy = val_PD_healthy.drop(columns='group')
y_val_PD_healthy = val_PD_healthy['group']
X_test_PD_healthy = test_PD_healthy.drop(columns='group')
y_test_PD_healthy = test_PD_healthy['group']


X_train_PDMCI_healthy = train_PDMCI_healthy.drop(columns='group')
y_train_PDMCI_healthy = train_PDMCI_healthy['group']
X_val_PDMCI_healthy = val_PDMCI_healthy.drop(columns='group')
y_val_PDMCI_healthy = val_PDMCI_healthy['group']
X_test_PDMCI_healthy = test_PDMCI_healthy.drop(columns='group')
y_test_PDMCI_healthy = test_PDMCI_healthy['group']

# %%
train_AD_healthy['group'].value_counts()
# Out:
# Healthy    110
# AD_MCI      41
# Name: group, dtype: int64

# %%
print('AD_healthy')
print('train\n',np.shape(np.array(X_train_AD_healthy)),'\n',np.shape(np.array(y_train_AD_healthy)),'\n',train_AD_healthy['group'].value_counts())
print('val\n',np.shape(np.array(X_val_AD_healthy)),'\n',np.shape(np.array(y_val_AD_healthy)),'\n',val_AD_healthy['group'].value_counts())
print('test\n',np.shape(np.array(X_test_AD_healthy)),'\n',np.shape(np.array(y_test_AD_healthy)),'\n',test_AD_healthy['group'].value_counts())

print('\nPD_healthy')
print('train\n',np.shape(np.array(X_train_PD_healthy)),'\n',np.shape(np.array(y_train_PD_healthy)),'\n',train_PD_healthy['group'].value_counts())
print('val\n',np.shape(np.array(X_val_PD_healthy)),'\n',np.shape(np.array(y_val_PD_healthy)),'\n',val_PD_healthy['group'].value_counts())
print('test\n',np.shape(np.array(X_test_PD_healthy)),'\n',np.shape(np.array(y_test_PD_healthy)),'\n',test_PD_healthy['group'].value_counts())

print('\nPDMCI_healthy')
print('train\n',np.shape(np.array(X_train_PDMCI_healthy)),'\n',np.shape(np.array(y_train_PDMCI_healthy)),'\n',train_PDMCI_healthy['group'].value_counts())
print('val\n',np.shape(np.array(X_val_PDMCI_healthy)),'\n',np.shape(np.array(y_val_PDMCI_healthy)),'\n',val_PDMCI_healthy['group'].value_counts())
print('test\n',np.shape(np.array(X_test_PDMCI_healthy)),'\n',np.shape(np.array(y_test_PDMCI_healthy)),'\n',test_PDMCI_healthy['group'].value_counts())
# Out:
# AD_healthy
# train
#  (151, 1138)
#  (151,)
#  Healthy    110
# AD_MCI      41
# Name: group, dtype: int64
# val
#  (26, 1138)
#  (26,)
#  Healthy    22
# AD_MCI      4
# Name: group, dtype: int64
# test
#  (30, 1138)
#  (30,)
#  Healthy    24
# AD_MCI      6
# Name: group, dtype: int64
#
# PD_healthy
# train
#  (140, 1138)
#  (140,)
#  Healthy    110
# PD          30
# Name: group, dtype: int64
# val
#  (24, 1138)
#  (24,)
#  Healthy    22
# PD          2
# Name: group, dtype: int64
# test
#  (28, 1138)
#  (28,)
#  Healthy    24
# PD          4
# Name: group, dtype: int64
#
# PDMCI_healthy
# train
#  (131, 1138)
#  (131,)
#  Healthy       110
# PD_MCI_LBD     21
# Name: group, dtype: int64
# val
#  (131, 1138)
#  (131,)
#  Healthy       110
# PD_MCI_LBD     21
# Name: group, dtype: int64
# test
#  (32, 1138)
#  (32,)
#  Healthy       24
# PD_MCI_LBD     8
# Name: group, dtype: int64

# %% [markdown]
# Inspecting the isolated condition groups for data size... PDMCI is pretty small

# %% [markdown]
# Define model to feature select with:

# %%
model = sklearn.linear_model.RidgeClassifier()
sfs = mlxtend.feature_selection.SequentialFeatureSelector(model, k_features=20, forward=True,verbose=2,n_jobs=-1)

# %% [markdown]
# Start with AD_MCI

# %%
sfs_AD = sfs.fit(X_train_AD_healthy,y_train_AD_healthy)
top20_AD = sfs_AD.k_feature_names_
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 444 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 1138 out of 1138 | elapsed:    2.9s finished
#
# [2023-02-26 06:16:33] Features: 1/20 -- score: 0.8212903225806452[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1137 out of 1137 | elapsed:    1.9s finished
#
# [2023-02-26 06:16:35] Features: 2/20 -- score: 0.8681720430107529[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1136 out of 1136 | elapsed:    1.8s finished
#
# [2023-02-26 06:16:37] Features: 3/20 -- score: 0.8879569892473118[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1135 out of 1135 | elapsed:    1.9s finished
#
# [2023-02-26 06:16:39] Features: 4/20 -- score: 0.9008602150537636[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1134 out of 1134 | elapsed:    1.9s finished
#
# [2023-02-26 06:16:41] Features: 5/20 -- score: 0.9210752688172044[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1133 out of 1133 | elapsed:    2.0s finished
#
# [2023-02-26 06:16:43] Features: 6/20 -- score: 0.9408602150537634[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1132 out of 1132 | elapsed:    2.0s finished
#
# [2023-02-26 06:16:45] Features: 7/20 -- score: 0.9475268817204301[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1131 out of 1131 | elapsed:    2.1s finished
#
# [2023-02-26 06:16:47] Features: 8/20 -- score: 0.9475268817204301[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1130 out of 1130 | elapsed:    1.9s finished
#
# [2023-02-26 06:16:49] Features: 9/20 -- score: 0.9475268817204301[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1129 out of 1129 | elapsed:    2.0s finished
#
# [2023-02-26 06:16:51] Features: 10/20 -- score: 0.9475268817204301[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1128 out of 1128 | elapsed:    2.1s finished
#
# [2023-02-26 06:16:53] Features: 11/20 -- score: 0.9475268817204301[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 1127 out of 1127 | elapsed:    2.1s finished
#
# [2023-02-26 06:16:56] Features: 12/20 -- score: 0.9475268817204301[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 1126 out of 1126 | elapsed:    2.1s finished
#
# [2023-02-26 06:16:58] Features: 13/20 -- score: 0.9475268817204301[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1125 out of 1125 | elapsed:    2.0s finished
#
# [2023-02-26 06:17:00] Features: 14/20 -- score: 0.9475268817204301[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1124 out of 1124 | elapsed:    2.1s finished
#
# [2023-02-26 06:17:02] Features: 15/20 -- score: 0.9475268817204301[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1123 out of 1123 | elapsed:    2.1s finished
#
# [2023-02-26 06:17:04] Features: 16/20 -- score: 0.9475268817204301[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1122 out of 1122 | elapsed:    2.0s finished
#
# [2023-02-26 06:17:07] Features: 17/20 -- score: 0.9475268817204301[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1121 out of 1121 | elapsed:    2.0s finished
#
# [2023-02-26 06:17:09] Features: 18/20 -- score: 0.9475268817204301[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 1120 out of 1120 | elapsed:    2.1s finished
#
# [2023-02-26 06:17:11] Features: 19/20 -- score: 0.9475268817204301[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1119 out of 1119 | elapsed:    2.1s finished
#
# [2023-02-26 06:17:13] Features: 20/20 -- score: 0.9475268817204301

# %%
top20_AD = list(top20_AD)
print('Top 20 AD Proteins:',top20_AD)
# Out:
# Top 20 AD Proteins: ['LVX54', 'KVD15', 'KV311', 'HV601', 'HV374', 'VTM2B', 'SIRB1', 'QSOX1', 'NRP1', 'CLU', 'CAH11', 'TNR21', 'DDAH1', 'PPN', 'PDYN', 'TAU', 'AK1C1', 'TSP2', 'GLT10', 'ENPP5']

# %%
top20_AD = ['LVX54', 'KVD15', 'KV311', 'HV601', 'HV374', 'VTM2B', 'SIRB1', 'QSOX1', 'NRP1', 'CLU', 'CAH11', 'TNR21', 'DDAH1', 'PPN', 'PDYN', 'TAU', 'AK1C1', 'TSP2', 'GLT10', 'ENPP5']

# %%
sfs_PD = sfs.fit(X_train_PD_healthy,y_train_PD_healthy)
top20_PD = sfs_PD.k_feature_names_
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 1138 out of 1138 | elapsed:    1.6s finished
#
# [2023-02-26 06:20:13] Features: 1/20 -- score: 0.8071428571428572[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1137 out of 1137 | elapsed:    1.8s finished
#
# [2023-02-26 06:20:15] Features: 2/20 -- score: 0.8285714285714285[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1136 out of 1136 | elapsed:    1.8s finished
#
# [2023-02-26 06:20:17] Features: 3/20 -- score: 0.8571428571428571[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1135 out of 1135 | elapsed:    1.9s finished
#
# [2023-02-26 06:20:19] Features: 4/20 -- score: 0.8714285714285713[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1134 out of 1134 | elapsed:    1.9s finished
#
# [2023-02-26 06:20:21] Features: 5/20 -- score: 0.8857142857142858[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1133 out of 1133 | elapsed:    2.0s finished
#
# [2023-02-26 06:20:24] Features: 6/20 -- score: 0.8928571428571429[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 1132 out of 1132 | elapsed:    2.1s finished
#
# [2023-02-26 06:20:26] Features: 7/20 -- score: 0.9[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1131 out of 1131 | elapsed:    1.9s finished
#
# [2023-02-26 06:20:28] Features: 8/20 -- score: 0.9071428571428571[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1130 out of 1130 | elapsed:    1.9s finished
#
# [2023-02-26 06:20:30] Features: 9/20 -- score: 0.9214285714285715[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1129 out of 1129 | elapsed:    1.9s finished
#
# [2023-02-26 06:20:32] Features: 10/20 -- score: 0.9214285714285715[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1128 out of 1128 | elapsed:    2.0s finished
#
# [2023-02-26 06:20:34] Features: 11/20 -- score: 0.9214285714285715[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1127 out of 1127 | elapsed:    2.0s finished
#
# [2023-02-26 06:20:36] Features: 12/20 -- score: 0.9214285714285715[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1126 out of 1126 | elapsed:    2.0s finished
#
# [2023-02-26 06:20:38] Features: 13/20 -- score: 0.9214285714285715[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1125 out of 1125 | elapsed:    1.9s finished
#
# [2023-02-26 06:20:40] Features: 14/20 -- score: 0.9214285714285715[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1124 out of 1124 | elapsed:    2.0s finished
#
# [2023-02-26 06:20:43] Features: 15/20 -- score: 0.9214285714285715[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1123 out of 1123 | elapsed:    2.0s finished
#
# [2023-02-26 06:20:45] Features: 16/20 -- score: 0.9214285714285715[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1122 out of 1122 | elapsed:    2.1s finished
#
# [2023-02-26 06:20:47] Features: 17/20 -- score: 0.9214285714285715[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1121 out of 1121 | elapsed:    2.0s finished
#
# [2023-02-26 06:20:49] Features: 18/20 -- score: 0.9214285714285715[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1120 out of 1120 | elapsed:    2.0s finished
#
# [2023-02-26 06:20:51] Features: 19/20 -- score: 0.9214285714285715[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1119 out of 1119 | elapsed:    2.1s finished
#
# [2023-02-26 06:20:53] Features: 20/20 -- score: 0.9214285714285715

# %%
top20_PD = list(top20_PD)
print('Top 20 PD Proteins:',top20_PD)
# Out:
# Top 20 PD Proteins: ['LV218', 'KV240', 'HV404', 'KV127', 'KVD30', 'KVD15', 'LV136', 'A0A075B7F0', 'HV43D', 'HV428', 'A0A0J9YWU9', 'KVD12', 'APOL1', 'CHAD', 'ENO1', 'CO8A', 'H90B2', 'HLAC', 'PPIB', 'MMP17']

# %%
top20_PD = ['LV218', 'KV240', 'HV404', 'KV127', 'KVD30', 'KVD15', 'LV136', 'A0A075B7F0', 'HV43D', 'HV428', 'A0A0J9YWU9', 'KVD12', 'APOL1', 'CHAD', 'ENO1', 'CO8A', 'H90B2', 'HLAC', 'PPIB', 'MMP17']

# %%
sfs_PDMCI = sfs.fit(X_train_PDMCI_healthy,y_train_PDMCI_healthy)
top20_PDMCI = sfs_PDMCI.k_feature_names_
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 1138 out of 1138 | elapsed:    1.7s finished
#
# [2023-02-26 06:22:10] Features: 1/20 -- score: 0.8549857549857549[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1137 out of 1137 | elapsed:    1.9s finished
#
# [2023-02-26 06:22:12] Features: 2/20 -- score: 0.8626780626780628[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1136 out of 1136 | elapsed:    1.9s finished
#
# [2023-02-26 06:22:14] Features: 3/20 -- score: 0.8777777777777779[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1135 out of 1135 | elapsed:    1.9s finished
#
# [2023-02-26 06:22:16] Features: 4/20 -- score: 0.8854700854700855[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 1134 out of 1134 | elapsed:    1.9s finished
#
# [2023-02-26 06:22:18] Features: 5/20 -- score: 0.8931623931623932[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1133 out of 1133 | elapsed:    2.0s finished
#
# [2023-02-26 06:22:20] Features: 6/20 -- score: 0.9005698005698006[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1132 out of 1132 | elapsed:    2.1s finished
#
# [2023-02-26 06:22:22] Features: 7/20 -- score: 0.9082621082621085[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1131 out of 1131 | elapsed:    2.0s finished
#
# [2023-02-26 06:22:24] Features: 8/20 -- score: 0.9082621082621085[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1130 out of 1130 | elapsed:    2.0s finished
#
# [2023-02-26 06:22:26] Features: 9/20 -- score: 0.9085470085470086[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1129 out of 1129 | elapsed:    2.0s finished
#
# [2023-02-26 06:22:29] Features: 10/20 -- score: 0.9088319088319089[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1128 out of 1128 | elapsed:    2.0s finished
#
# [2023-02-26 06:22:31] Features: 11/20 -- score: 0.9236467236467238[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1127 out of 1127 | elapsed:    2.0s finished
#
# [2023-02-26 06:22:33] Features: 12/20 -- score: 0.9390313390313392[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1126 out of 1126 | elapsed:    2.1s finished
#
# [2023-02-26 06:22:35] Features: 13/20 -- score: 0.9467236467236468[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1125 out of 1125 | elapsed:    2.0s finished
#
# [2023-02-26 06:22:37] Features: 14/20 -- score: 0.9467236467236468[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1124 out of 1124 | elapsed:    2.0s finished
#
# [2023-02-26 06:22:39] Features: 15/20 -- score: 0.9467236467236468[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 1123 out of 1123 | elapsed:    2.0s finished
#
# [2023-02-26 06:22:41] Features: 16/20 -- score: 0.9467236467236468[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 1122 out of 1122 | elapsed:    2.1s finished
#
# [2023-02-26 06:22:44] Features: 17/20 -- score: 0.9467236467236468[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 1121 out of 1121 | elapsed:    2.3s finished
#
# [2023-02-26 06:22:46] Features: 18/20 -- score: 0.9467236467236468[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 1120 out of 1120 | elapsed:    2.7s finished
#
# [2023-02-26 06:22:49] Features: 19/20 -- score: 0.9467236467236468[Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 696 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 1119 out of 1119 | elapsed:    2.6s finished
#
# [2023-02-26 06:22:52] Features: 20/20 -- score: 0.9467236467236468

# %%
top20_PDMCI = list(top20_PDMCI)
print('Top 20 PDMCI Proteins:',top20_PDMCI)
# Out:
# Top 20 PDMCI Proteins: ['LV861', 'LVX54', 'LV746', 'LV312', 'LV545', 'KVD15', 'KV621', 'HV309', 'TEX51', 'IGLO5', 'SHSA7', 'MATN2', 'VGF', 'PPN', 'PAI1', 'AK1C1', 'PLTP', 'LG3BP', 'KLH21', 'B2L12']

# %%
top20_PDMCI = ['LV861', 'LVX54', 'LV746', 'LV312', 'LV545', 'KVD15', 'KV621', 'HV309', 'TEX51', 'IGLO5', 'SHSA7', 'MATN2', 'VGF', 'PPN', 'PAI1', 'AK1C1', 'PLTP', 'LG3BP', 'KLH21', 'B2L12']

# %%
all_top_20 = []
all_top_20.append(top20_AD)
all_top_20.append(top20_PD)
all_top_20.append(top20_PDMCI)
all_top_20 = np.array(all_top_20)
all_top_20 = list(np.unique(all_top_20))
print(all_top_20)
# Out:
# ['A0A075B7F0', 'A0A0J9YWU9', 'AK1C1', 'APOL1', 'B2L12', 'CAH11', 'CHAD', 'CLU', 'CO8A', 'DDAH1', 'ENO1', 'ENPP5', 'GLT10', 'H90B2', 'HLAC', 'HV309', 'HV374', 'HV404', 'HV428', 'HV43D', 'HV601', 'IGLO5', 'KLH21', 'KV127', 'KV240', 'KV311', 'KV621', 'KVD12', 'KVD15', 'KVD30', 'LG3BP', 'LV136', 'LV218', 'LV312', 'LV545', 'LV746', 'LV861', 'LVX54', 'MATN2', 'MMP17', 'NRP1', 'PAI1', 'PDYN', 'PLTP', 'PPIB', 'PPN', 'QSOX1', 'SHSA7', 'SIRB1', 'TAU', 'TEX51', 'TNR21', 'TSP2', 'VGF', 'VTM2B']

# %%
# Out:
# ['A0A075B7F0', 'A0A0J9YWU9', 'AK1C1', 'APOL1', 'B2L12', 'CAH11', 'CHAD', 'CLU', 'CO8A', 'DDAH1', 'ENO1', 'ENPP5', 'GLT10', 'H90B2', 'HLAC', 'HV309', 'HV374', 'HV404', 'HV428', 'HV43D', 'HV601', 'IGLO5', 'KLH21', 'KV127', 'KV240', 'KV311', 'KV621', 'KVD12', 'KVD15', 'KVD30', 'LG3BP', 'LV136', 'LV218', 'LV312', 'LV545', 'LV746', 'LV861', 'LVX54', 'MATN2', 'MMP17', 'NRP1', 'PAI1', 'PDYN', 'PLTP', 'PPIB', 'PPN', 'QSOX1', 'SHSA7', 'SIRB1', 'TAU', 'TEX51', 'TNR21', 'TSP2', 'VGF', 'VTM2B']

# %% [markdown]
# Create three regressors for each disease conditions based on training data with only the top 20 biomarkers

# %%
X_train20_AD_healthy = train_AD_healthy[top20_AD]
y_train20_AD_healthy = train_AD_healthy['group']

X_train20_PD_healthy = train_PD_healthy[top20_PD]
y_train20_PD_healthy = train_PD_healthy['group']

X_train20_PDMCI_healthy = train_PDMCI_healthy[top20_PDMCI]
y_train20_PDMCI_healthy = train_PDMCI_healthy['group']

# %%
df = pd.DataFrame(data=y_train20_AD_healthy)

# %%
df.value_counts()
# Out:
# group
# Healthy    110
# AD_MCI      41
# dtype: int64

# %%
model = sklearn.linear_model.RidgeClassifier()
AD_binary_model = model.fit(X_train20_AD_healthy,y_train20_AD_healthy)
model = sklearn.linear_model.RidgeClassifier()
PD_binary_model = model.fit(X_train20_PD_healthy,y_train20_PD_healthy)
model = sklearn.linear_model.RidgeClassifier()
PDMCI_binary_model = model.fit(X_train20_PDMCI_healthy,y_train20_PDMCI_healthy)

# %% [markdown]
# Generate binary predictions for the validation data

# %%
val_data_conditions = pd.DataFrame(data=val_data['group'])

val_set_AD_predictions = []
for i in range(len(val_data)):
    ilocdf = pd.DataFrame(data=dict(val_data.iloc[i][top20_AD]),index=[0])
    prediction = AD_binary_model.predict(ilocdf)
    if prediction == 'Healthy':
        prediction = 'not_AD'
    # For some reason, the output of the model has brackets so this is elif ensures that the prediction column is just a string with no brackets
    elif prediction == 'AD_MCI':
        prediction = 'AD_MCI'
    val_set_AD_predictions.append(prediction)
val_data_conditions['AD_pred'] = val_set_AD_predictions


val_set_PD_predictions = []
for i in range(len(val_data)):
    ilocdf = pd.DataFrame(data=dict(val_data.iloc[i][top20_PD]),index=[0])
    prediction = PD_binary_model.predict(ilocdf)
    if prediction == 'Healthy':
        prediction = 'not_PD'
    elif prediction == 'PD':
        prediction = 'PD'
    val_set_PD_predictions.append(prediction)
val_data_conditions['PD_pred'] = val_set_PD_predictions

val_set_PDMCI_predictions = []
for i in range(len(val_data)):
    ilocdf = pd.DataFrame(data=dict(val_data.iloc[i][top20_PDMCI]),index=[0])
    prediction = PDMCI_binary_model.predict(ilocdf)
    if prediction == 'Healthy':
        prediction = 'not_PD_MCI_LBD'
    elif prediction == 'PD_MCI_LBD':
        prediction = 'PD_MCI_LBD'
    val_set_PDMCI_predictions.append(prediction)
val_data_conditions['PD_MCI_pred'] = val_set_PDMCI_predictions




val_data_conditions
# Out:
#          group AD_pred PD_pred     PD_MCI_pred
# 0      Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 1      Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 2      Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 3      Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 4      Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 5       AD_MCI  AD_MCI  not_PD      PD_MCI_LBD
# 6      Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 7   PD_MCI_LBD  AD_MCI  not_PD  not_PD_MCI_LBD
# 8      Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 9       AD_MCI  not_AD  not_PD  not_PD_MCI_LBD
# 10     Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 11  PD_MCI_LBD  not_AD  not_PD  not_PD_MCI_LBD
# 12     Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 13  PD_MCI_LBD  not_AD  not_PD  not_PD_MCI_LBD
# 14     Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 15      AD_MCI  AD_MCI  not_PD  not_PD_MCI_LBD
# 16  PD_MCI_LBD  not_AD  not_PD      PD_MCI_LBD
# 17  PD_MCI_LBD  AD_MCI  not_PD  not_PD_MCI_LBD
# 18     Healthy  AD_MCI  not_PD  not_PD_MCI_LBD
# 19     Healthy  not_AD      PD  not_PD_MCI_LBD
# 20     Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 21     Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 22     Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 23     Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 24  PD_MCI_LBD  not_AD      PD      PD_MCI_LBD
# 25      AD_MCI  AD_MCI  not_PD  not_PD_MCI_LBD
# 26     Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 27  PD_MCI_LBD  not_AD  not_PD  not_PD_MCI_LBD
# 28     Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 29     Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 30          PD  not_AD  not_PD  not_PD_MCI_LBD
# 31          PD  not_AD  not_PD  not_PD_MCI_LBD
# 32     Healthy  not_AD  not_PD  not_PD_MCI_LBD
# 33     Healthy  not_AD      PD  not_PD_MCI_LBD
# 34     Healthy  AD_MCI  not_PD  not_PD_MCI_LBD
# 35  PD_MCI_LBD  not_AD  not_PD  not_PD_MCI_LBD

# %% [markdown]
# ### Training the binary models on just the condition vs healthy frames

# %%
model = sklearn.linear_model.RidgeClassifier()
AD_binary_model = model.fit(X_train20_AD_healthy,y_train20_AD_healthy)
model = sklearn.linear_model.RidgeClassifier()
PD_binary_model = model.fit(X_train20_PD_healthy,y_train20_PD_healthy)
model = sklearn.linear_model.RidgeClassifier()
PDMCI_binary_model = model.fit(X_train20_PDMCI_healthy,y_train20_PDMCI_healthy)

# %%
def ridge_class_w_selected_features(frame,features,model,target='group'):
    model = sklearn.linear_model.RidgeClassifier()
    X = frame[features]
    y = frame[target]
    return model.score(X,y)

# %%
print('AD_healthy binary classifier scores')
print('Training data:',ridge_class_w_selected_features(train_AD_healthy,top20_AD,AD_binary_model))
print('Val data:',ridge_class_w_selected_features(val_AD_healthy,top20_AD,AD_binary_model))
print('Test data:',ridge_class_w_selected_features(test_AD_healthy,top20_AD,AD_binary_model))

print('\nPD_healthy binary classifier scores')
print('Training data:',ridge_class_w_selected_features(train_PD_healthy,top20_PD,PD_binary_model))
print('Val data:',ridge_class_w_selected_features(val_PD_healthy,top20_PD,PD_binary_model))
print('Test data:',ridge_class_w_selected_features(test_PD_healthy,top20_PD,PD_binary_model))

print('\nPD_MCI_healthy binary classifier scores')
print('Training data:',ridge_class_w_selected_features(train_PDMCI_healthy,top20_PDMCI,PDMCI_binary_model))
print('Val data:',ridge_class_w_selected_features(val_PDMCI_healthy,top20_PDMCI,PDMCI_binary_model))
print('Test data:',ridge_class_w_selected_features(test_PDMCI_healthy,top20_PDMCI,PDMCI_binary_model))
# Out:
# AD_healthy binary classifier scores
# Training data: 0.9271523178807947
# Val data: 0.8846153846153846
# Test data: 0.9
#
# PD_healthy binary classifier scores
# Training data: 0.9214285714285714
# Val data: 0.8333333333333334
# Test data: 0.8214285714285714
#
# PD_MCI_healthy binary classifier scores
# Training data: 0.9389312977099237
# Val data: 0.9389312977099237
# Test data: 0.6875

# %%
val_AD_healthy['group'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 val_AD_healthy['group'].value_counts()
#
# NameError: name 'val_AD_healthy' is not defined

# %%
def three_way_binary(frame,AD_features,PD_features,PDMCI_features,target='group'):
    three_way_df = pd.DataFrame()
    three_way_df['group'] = frame[target]
    
    AD_predictions = []
    for i in range(len(frame)):
        ilocdf = pd.DataFrame(data=dict(frame.iloc[i][AD_features]),index=[0])
        prediction = AD_binary_model.predict(ilocdf)
        if prediction == 'Healthy':
            prediction = 'none'
        # For some reason, the output of the model has brackets so this is elif ensures that the prediction column is just a string with no brackets
        elif prediction == 'AD_MCI':
            prediction = 'AD_MCI'
        AD_predictions.append(prediction)
    three_way_df['AD_pred'] = AD_predictions
    
    PD_predictions = []
    for i in range(len(frame)):
        ilocdf = pd.DataFrame(data=dict(frame.iloc[i][PD_features]),index=[0])
        prediction = PD_binary_model.predict(ilocdf)
        if prediction == 'Healthy':
            prediction = 'none'
        # For some reason, the output of the model has brackets so this is elif ensures that the prediction column is just a string with no brackets
        elif prediction == 'PD':
            prediction = 'PD'
        PD_predictions.append(prediction)
    three_way_df['PD_pred'] = PD_predictions    

    PDMCI_predictions = []
    for i in range(len(frame)):
        ilocdf = pd.DataFrame(data=dict(frame.iloc[i][PDMCI_features]),index=[0])
        prediction = PDMCI_binary_model.predict(ilocdf)
        if prediction == 'Healthy':
            prediction = 'none'
        # For some reason, the output of the model has brackets so this is elif ensures that the prediction column is just a string with no brackets
        elif prediction == 'PD':
            prediction = 'PD'
        PDMCI_predictions.append(prediction)
    three_way_df['PDMCI_pred'] = PDMCI_predictions
    
    return three_way_df

# %%
three_way_df = pd.DataFrame(data=three_way_binary(val_data,top20_AD,top20_PD,top20_PDMCI), columns=['actual','AD_pred','PD_pred','PDMCI_pred'])

# %%
three_way_df = three_way_binary(test_data,top20_AD,top20_PD,top20_PDMCI)

# %%
three_way_df
# Out:
#          group AD_pred PD_pred    PDMCI_pred
# 0      Healthy    none    none          none
# 1   PD_MCI_LBD    none    none          none
# 2      Healthy    none    none  [PD_MCI_LBD]
# 3      Healthy    none      PD          none
# 4           PD    none    none          none
# 5           PD    none    none          none
# 6      Healthy    none    none          none
# 7      Healthy    none    none          none
# 8       AD_MCI  AD_MCI    none          none
# 9      Healthy    none    none  [PD_MCI_LBD]
# 10     Healthy    none    none          none
# 11     Healthy    none    none          none
# 12     Healthy    none    none          none
# 13     Healthy    none    none          none
# 14     Healthy    none    none          none
# 15     Healthy    none    none          none
# 16  PD_MCI_LBD    none    none          none
# 17      AD_MCI    none      PD          none
# 18      AD_MCI  AD_MCI      PD  [PD_MCI_LBD]
# 19  PD_MCI_LBD    none      PD          none
# 20     Healthy    none    none          none
# 21      AD_MCI  AD_MCI    none          none
# 22     Healthy    none    none          none
# 23     Healthy    none    none          none
# 24     Healthy    none    none          none
# 25          PD    none    none          none
# 26     Healthy    none    none          none
# 27     Healthy    none    none          none
# 28  PD_MCI_LBD    none    none          none
# 29  PD_MCI_LBD    none    none          none
# 30     Healthy  AD_MCI    none          none
# 31     Healthy    none    none          none
# 32     Healthy    none    none          none
# 33  PD_MCI_LBD    none      PD          none
# 34          PD    none    none          none
# 35      AD_MCI  AD_MCI    none  [PD_MCI_LBD]
# 36      AD_MCI    none    none          none
# 37  PD_MCI_LBD    none    none          none
# 38     Healthy    none    none          none
# 39     Healthy    none    none          none
# 40  PD_MCI_LBD  AD_MCI    none          none
# 41     Healthy    none    none          none

# %% [markdown]
# ### Training the binary models on binary datasets with all conditions included

# %%
binary_data_AD_train = train_data.replace(to_replace=['PD','PD_MCI_LBD','Healthy'],value='not_AD')
binary_data_AD_val = val_data.replace(to_replace=['PD','PD_MCI_LBD','Healthy'],value='not_AD')
binary_data_AD_test = test_data.replace(to_replace=['PD','PD_MCI_LBD','Healthy'],value='not_AD')

binary_data_PD_train = train_data.replace(to_replace=['AD_MCI','PD_MCI_LBD','Healthy'],value='not_AD')
binary_data_PD_val = val_data.replace(to_replace=['AD_MCI','PD_MCI_LBD','Healthy'],value='not_PD')
binary_data_PD_test = test_data.replace(to_replace=['AD_MCI','PD_MCI_LBD','Healthy'],value='not_PD')

binary_data_PDMCI_train = train_data.replace(to_replace=['PD','AD_MCI','Healthy'],value='not_PDMCI')
binary_data_PDMCI_val = val_data.replace(to_replace=['PD','AD_MCI','Healthy'],value='not_PDMCI')
binary_data_PDMCI_test = test_data.replace(to_replace=['PD','AD_MCI','Healthy'],value='not_PDMCI')

# %%
binary_data_PD_test
# Out:
#      group       KV37      LV469      LV861      LVX54      LV746      LV218  \
# 0   not_PD  29.095311  22.914746  23.465673  24.543944  25.807818  24.247465
# 1   not_PD  28.616975  22.266832  22.600108  18.431455  24.773448  23.408153
# 2   not_PD  28.004649  22.263307  23.664214  21.614948  24.897457  23.717144
# 3   not_PD  29.058831  22.567414  23.916463  21.914058  25.557151  23.946191
# 4       PD  28.881609  22.658470  21.910208  20.466290  24.527000  24.004398
# 5       PD  28.833728  22.104417  23.626751  15.248723  24.636469  24.695328
# 6   not_PD  28.215222  23.456092  23.948540  22.495857  25.648726  24.086456
# 7   not_PD  26.758964  21.118196  22.778541  21.002959  23.999265  23.168366
# 8   not_PD  28.403123  21.703692  20.310644  20.348068  23.664406  23.811062
# 9   not_PD  28.468191  23.427728  23.605409  15.131982  25.252005  23.000942
# 10  not_PD  28.537116  22.989016  24.588337  21.393064  25.921756  24.199699
# 11  not_PD  28.696257  22.467258  23.155593  20.972625  25.134314  23.755063
# 12  not_PD  29.194622  23.402068  24.385963  20.001444  25.979592  24.813235
# 13  not_PD  28.798293  22.931851  25.102174  22.548926  24.896322  24.679178
# 14  not_PD  30.124669  24.282538  24.998441  23.028919  27.160290  25.113300
# 15  not_PD  28.354472  22.479693  21.156709  17.083196  25.559899  24.210522
# 16  not_PD  28.735697  22.842436  24.235382  22.927039  25.838145  25.330213
# 17  not_PD  27.128300  22.490591  24.366686  14.622427  24.308411  23.808042
# 18  not_PD  28.158388  21.245025  23.028950  22.007410  24.194921  23.733433
# 19  not_PD  29.919698  23.727972  24.024882  16.081469  26.457936  25.880806
# 20  not_PD  28.668744  22.004868  22.952458  22.928005  25.220589  24.177335
# 21  not_PD  28.609396  22.340351  24.091218  12.599989  25.223221  24.262038
# 22  not_PD  29.100051  22.462874  24.473758  17.437616  25.474677  24.017599
# 23  not_PD  29.103797  22.885762  23.736000  23.113655  25.736905  25.338306
# 24  not_PD  30.388404  23.476030  19.487540  23.768426  26.832218  24.795448
# 25      PD  28.950330  22.522953  22.700164  21.172241  24.101664  24.065582
# 26  not_PD  28.035137  22.667095  23.140189  20.695508  25.190450  23.827819
# 27  not_PD  28.397518  23.305656  23.200973  23.440833  25.208389  23.630554
# 28  not_PD  28.688139  24.618477  22.015187  22.370303  26.611583  25.115721
# 29  not_PD  28.582888  24.057798  23.068824  18.759128  25.654204  24.414183
# 30  not_PD  28.456244  22.700281  22.879598  21.000115  24.601457  23.695054
# 31  not_PD  29.220417  23.687103  23.560029  19.731497  26.462628  24.942517
# 32  not_PD  28.716420  23.102469  22.343367  20.919657  25.906449  23.393289
# 33  not_PD  29.521710  22.905752  23.249080  23.086458  26.198278  24.811119
# 34      PD  30.050203  24.144529  25.690239  23.128879  25.919865  26.210455
# 35  not_PD  28.212282  22.520379  24.504620  20.681650  26.287648  25.020801
# 36  not_PD  27.667623  21.564017  24.167031  16.888347  25.269881  24.680729
# 37  not_PD  30.006075  24.763642  27.015788  24.093391  27.359107  25.293610
# 38  not_PD  28.018209  21.405658  23.015360  19.216271  25.658238  23.756359
# 39  not_PD  28.709552  23.849001  25.174622  22.915326  26.023221  25.131375
# 40  not_PD  29.246371  24.053361  24.786591  21.015089  26.771274  24.841791
# 41  not_PD  30.079720  23.419101  23.267171  23.549589  26.959357  25.990690
#
#         LV316      LV312      LV310  ...      ARMD4      C1QT5      B2L12  \
# 0   23.014983  22.783692  22.133837  ...  18.365925  19.746515  28.184519
# 1   22.863952  22.578072  22.425962  ...  14.231228  20.224879  28.149344
# 2   23.635040  22.718097  23.194275  ...  17.253986  20.178723  28.817759
# 3   22.782418  22.172497  21.511763  ...  18.079633  19.776229  28.034288
# 4   21.884848  21.021232  20.963709  ...  20.069476  19.639023  27.739303
# 5   22.307081  21.567867  21.492075  ...  17.381783  20.219334  28.297581
# 6   22.618295  21.972739  21.755923  ...  18.088279  20.327758  28.753138
# 7   22.174694  21.250284  21.075635  ...  19.532082  19.998261  28.149196
# 8   22.956995  23.741478  22.513721  ...  14.347183  20.141805  28.642463
# 9   22.159893  21.680271  21.465589  ...  18.593808  19.932572  28.170378
# 10  22.721547  21.747486  21.943443  ...  18.629993  19.534754  27.773279
# 11  23.098909  22.605508  23.042370  ...  18.512586  20.215579  28.550519
# 12  23.036168  22.458694  22.260650  ...  19.825933  20.003480  27.764000
# 13  22.896616  22.315921  22.376141  ...  18.112954  19.677545  27.926319
# 14  24.113706  23.841721  23.729933  ...  17.166557  19.625257  27.918850
# 15  23.157393  22.245965  22.302972  ...  19.778674  19.901565  28.066964
# 16  23.921735  22.577081  22.687331  ...  18.341487  19.956441  27.042614
# 17  29.455989  24.823334  28.679064  ...  17.993971  19.951241  28.496336
# 18  23.718723  23.222627  23.379965  ...  17.898777  19.695973  28.684028
# 19  24.292395  23.740719  23.743020  ...  17.106943  19.933405  27.994244
# 20  23.119445  22.341231  22.514101  ...  17.189209  20.783094  28.124053
# 21  23.222251  23.273881  22.437653  ...  18.328312  19.709989  27.870216
# 22  23.232650  22.863843  22.277047  ...  19.040133  19.669362  27.891991
# 23  23.994966  22.934528  23.955509  ...  17.088910  19.463907  27.619431
# 24  24.433762  23.394579  23.693967  ...  20.298447  19.724912  27.926998
# 25  22.375415  22.245717  21.713662  ...  18.114293  19.794076  28.186614
# 26  22.482952  21.603847  21.761703  ...  18.117260  19.686369  27.927140
# 27  23.179669  22.489165  22.717836  ...  18.149397  19.894362  27.855965
# 28  24.812864  22.872144  23.236595  ...  15.734273  20.080069  28.556119
# 29  22.596218  22.270587  21.800792  ...  18.665579  20.650882  28.215642
# 30  23.222102  22.634190  23.083013  ...  18.175776  19.894158  28.450265
# 31  24.132078  23.437494  22.600439  ...  18.888746  20.346683  28.212453
# 32  23.127369  22.458586  22.512898  ...  17.764629  19.995409  28.410015
# 33  24.141279  23.392960  23.576161  ...  17.462882  20.147582  28.318187
# 34  24.008489  23.173371  23.313321  ...  15.504891  19.697293  27.777798
# 35  23.176368  23.293055  22.188477  ...  18.463314  20.359109  28.559184
# 36  22.723880  21.798155  21.956326  ...  18.769538  19.967159  28.612714
# 37  24.343795  23.748932  23.510852  ...  17.612985  19.641403  28.041693
# 38  22.395597  22.025489  22.581838  ...  18.306604  19.997289  28.425689
# 39  23.315201  22.351902  22.123802  ...  18.282683  19.801451  27.701791
# 40  23.440783  23.523669  22.360203  ...  16.514149  19.182719  28.416486
# 41  24.896747  22.929109  24.421521  ...  18.857954  19.676769  27.157026
#
#         PLXA4      B3GN2      PCDGL      AGRB1       RECK       PSA1  \
# 0   17.857970  19.919932  18.875353  21.328279  19.894098  20.480407
# 1   18.816604  20.509034  18.183611  22.333313  20.090041  20.840459
# 2   16.759801  19.488997  18.065153  21.283092  19.138285  20.659743
# 3   18.131934  19.962431  18.103656  21.350020  19.683708  20.529492
# 4   19.326313  20.487923  18.559469  20.629128  18.917739  20.519102
# 5   18.084594  20.164663  15.770773  20.877399  19.236433  20.596072
# 6   18.044162  20.401900  17.933399  21.343500  20.138425  20.360648
# 7   19.710384  20.792139  19.127583  22.158528  19.883552  21.055747
# 8   17.506197  20.145225  19.185181  21.211442  20.375947  20.517760
# 9   19.002192  20.680688  18.725862  21.332560  19.889075  20.481241
# 10  17.955645  20.373433  17.766658  21.131266  19.901424  21.225874
# 11  18.444217  20.377153  17.331065  20.794655  20.203462  20.220405
# 12  18.531199  19.818622  17.791060  21.709985  20.102291  20.605781
# 13  17.671162  19.818010  17.961635  21.098655  19.362535  20.449046
# 14  15.328859  19.243746  17.591109  19.549196  19.874510  20.184451
# 15  18.752614  20.070644  14.825305  21.393498  20.135779  20.611369
# 16  18.291305  20.093467  17.796253  21.364415  19.641589  19.907416
# 17  18.446814  20.868856  17.193557  21.247936  19.375673  20.619291
# 18  17.302790  19.848980  19.145579  21.194587  19.908307  20.921792
# 19  17.190342  19.852474  16.134371  20.871031  19.228681  20.599270
# 20  17.906833  20.005546  17.539303  21.701524  19.609233  20.285003
# 21  18.507433  20.228250  18.898499  21.127653  20.081058  20.257007
# 22  18.441588  19.794026  18.521219  21.076516  19.577420  20.399699
# 23  18.553526  20.309284  18.117003  21.208468  18.696486  19.652520
# 24  15.201141  18.759748  16.929572  21.330372  19.898818  20.480486
# 25  18.751002  19.836041  18.701221  21.598704  20.351174  20.477294
# 26  17.675461  19.823666  17.968285  21.102074  19.372148  20.449088
# 27  18.047170  20.352635  19.486925  20.831241  19.631246  20.370400
# 28  17.685923  19.719897  16.016064  21.321637  19.743216  20.261703
# 29  18.072443  20.145598  18.760829  20.869544  19.226996  20.596207
# 30  19.046439  20.752423  18.774789  21.823268  19.726687  20.425893
# 31  17.630311  19.824133  18.310665  21.404492  19.167852  19.246514
# 32  18.439537  19.958031  18.134609  21.854467  19.946183  20.449536
# 33  18.800890  19.480223  17.868328  20.853942  17.435981  21.216134
# 34  17.535721  19.536991  16.135962  19.915515  19.336850  19.967031
# 35  17.084283  20.286652  17.961467  20.204779  20.353522  20.819426
# 36  18.452509  20.884110  18.847436  21.254113  19.386180  20.619278
# 37  17.502125  19.568337  17.409305  20.488479  18.954178  20.434083
# 38  18.168776  19.647687  18.316475  21.395957  19.031496  19.705424
# 39  17.758239  20.461068  19.103445  21.046120  19.730255  20.013038
# 40  17.152153  18.500232  17.589554  20.666756  19.369111  21.516807
# 41  16.605011  19.124234  18.159001  21.040314  20.463638  20.127548
#
#         F174A
# 0   24.265616
# 1   24.291441
# 2   24.430869
# 3   24.247193
# 4   24.136346
# 5   24.198477
# 6   24.511899
# 7   24.668104
# 8   24.612473
# 9   24.267293
# 10  24.220519
# 11  24.431621
# 12  24.367738
# 13  24.182195
# 14  23.946683
# 15  24.296829
# 16  23.885166
# 17  24.249734
# 18  24.137703
# 19  24.198666
# 20  24.062629
# 21  24.685999
# 22  24.200838
# 23  23.676696
# 24  24.267104
# 25  24.111739
# 26  24.184804
# 27  24.814945
# 28  24.173198
# 29  24.195906
# 30  24.340924
# 31  24.129118
# 32  24.215516
# 33  24.189253
# 34  23.714823
# 35  23.993346
# 36  24.254993
# 37  23.998236
# 38  24.756412
# 39  24.313949
# 40  23.914240
# 41  23.749085
#
# [42 rows x 1139 columns]

# %%
def

# %%
print('AD_all binary classifier scores')
print('Training data:',ridge_class_w_selected_features(train_AD_healthy,top20_AD,AD_binary_model))
print('Val data:',ridge_class_w_selected_features(val_AD_healthy,top20_AD,AD_binary_model))
print('Test data:',ridge_class_w_selected_features(test_AD_healthy,top20_AD,AD_binary_model))
# Out:
# not_AD    161
# AD_MCI     41
# Name: group, dtype: int64

# %%
def train_ridge_selected_features (train,val,test,features,target='group'):
    # Train the model
    model = sklearn.linear_model.RidgeClassifier()
    train_X = train[features]
    train_y = train[target]
    model.fit(train_X,train_y)
    
    val_X = val[features]
    val_y = val[target]
    
    test_X = test[features]
    test_y = test[target]
    
    # Score the model
    print('Training score:',model.score(train_X,train_y))
    print('Val score:',model.score(val_X,val_y))
    print('Test score:',model.score(test_X,test_y))
    
    return model

# %%
print('AD Binary classifier scores:')
train_ridge_selected_features(binary_data_AD_train,binary_data_AD_val,binary_data_AD_test,top20_AD)

print('\nPD Binary classifier scores:')
train_ridge_selected_features(binary_data_PD_train,binary_data_PD_val,binary_data_PD_test,top20_PD)

print('\nPD_MCI Binary classifier scores:')
train_ridge_selected_features(binary_data_PDMCI_train,binary_data_PDMCI_val,binary_data_PDMCI_test,top20_PDMCI)
# Out:
# AD Binary classifier scores:
# Training score: 0.8861386138613861
# Val score: 0.9444444444444444
# Test score: 0.9047619047619048
#
# PD Binary classifier scores:
# Training score: 0.8861386138613861
# Val score: 0.0
# Test score: 0.0
#
# PD_MCI Binary classifier scores:
# Training score: 0.9158415841584159
# Val score: 0.7777777777777778
# Test score: 0.7857142857142857
# RidgeClassifier()

# %%
def multi_class_from_binary(frame,features,model,target='group')
